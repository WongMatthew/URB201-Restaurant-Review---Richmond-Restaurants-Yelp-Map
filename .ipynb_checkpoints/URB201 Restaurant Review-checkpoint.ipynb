# %%
# !pip install folium
# Out:
# Collecting folium
#   Using cached folium-0.18.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: requests in c:\users\matthew wong\anaconda3\lib\site-packages (from folium) (2.28.2)
# Collecting branca>=0.6.0
#   Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: xyzservices in c:\users\matthew wong\anaconda3\lib\site-packages (from folium) (2025.1.0)
# Requirement already satisfied: numpy in c:\users\matthew wong\appdata\roaming\python\python38\site-packages (from folium) (1.19.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\matthew wong\anaconda3\lib\site-packages (from folium) (2.11.3)
# Collecting jinja2>=2.9
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matthew wong\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matthew wong\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matthew wong\anaconda3\lib\site-packages (from requests->folium) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matthew wong\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\matthew wong\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Installing collected packages: jinja2, branca, folium
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# Successfully installed branca-0.8.1 folium-0.18.0 jinja2-3.1.6
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-estimator: [Errno 2] No such file or directory: 'c:\\users\\matthew wong\\anaconda3\\lib\\site-packages\\tensorflow_estimator-2.5.0.dist-info\\METADATA'
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# sphinx 4.0.1 requires Jinja2<3.0,>=2.3, but you have jinja2 3.1.6 which is incompatible.
# sphinx 4.0.1 requires MarkupSafe<2.0, but you have markupsafe 2.1.5 which is incompatible.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\matthew wong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\matthew wong\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import time
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import json

# %%
API_KEY = 'nuh uh'  
HEADERS = {'Authorization': f'Bearer {API_KEY}'}
SEARCH_ENDPOINT = 'https://api.yelp.com/v3/businesses/search'

# %%
# search for all major restaurants within all postal codes in richmond
categories = ['chinese', 'japanese', 'korean', 'vietnamese', 'indian', 'mexican', 'thai', 'italian', 'pizza', 'burgers']
postal_codes = ['V6V', 'V6W', 'V6X', 'V6Y', 'V7A', 'V7C', 'V7E']

all_results = []

# way to by pass post request restaurant limit (50)
# request restaurants that fall within category in specific postal code
for category in categories:
    for postal in postal_codes:
        print(f"Searching: {category} in {postal}...")
        offset = 0
        while offset <= 190: 
            params = {
                'location': f'{postal}, Richmond, BC',
                'categories': f'{category},restaurants',
                'limit': 50,
                'offset': offset
            }
            
            # make request + error handling
            response = requests.get(SEARCH_ENDPOINT, headers=HEADERS, params=params)
            if response.status_code != 200:
                print(f"Error {response.status_code}: {response.text}")
                break

            data = response.json()
            businesses = data.get('businesses', [])
            if not businesses:
                break

            # add to array
            for biz in businesses:
                all_results.append({
                    'id': biz['id'],
                    'name': biz['name'],
                    'address': ", ".join(biz['location']['display_address']),
                    'latitude': biz['coordinates']['latitude'],
                    'longitude': biz['coordinates']['longitude'],
                    'categories': ", ".join([cat['title'] for cat in biz.get('categories', [])])
                })

            offset += 50
            time.sleep(0.5)

# drop duplicates
df = pd.DataFrame(all_results)
df.drop_duplicates(subset='id', inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
# Searching: chinese in V6V...
# Searching: chinese in V6W...
# Searching: chinese in V6X...
# Searching: chinese in V6Y...
# Searching: chinese in V7A...
# Searching: chinese in V7C...
# Searching: chinese in V7E...
# Searching: japanese in V6V...
# Searching: japanese in V6W...
# Searching: japanese in V6X...
# Searching: japanese in V6Y...
# Searching: japanese in V7A...
# Searching: japanese in V7C...
# Searching: japanese in V7E...
# Searching: korean in V6V...
# Searching: korean in V6W...
# Searching: korean in V6X...
# Searching: korean in V6Y...
# Searching: korean in V7A...
# Searching: korean in V7C...
# Searching: korean in V7E...
# Searching: vietnamese in V6V...
# Searching: vietnamese in V6W...
# Searching: vietnamese in V6X...
# Searching: vietnamese in V6Y...
# Searching: vietnamese in V7A...
# Searching: vietnamese in V7C...
# Searching: vietnamese in V7E...
# Searching: indian in V6V...
# Searching: indian in V6W...
# Searching: indian in V6X...
# Searching: indian in V6Y...
# Searching: indian in V7A...
# Searching: indian in V7C...
# Searching: indian in V7E...
# Searching: mexican in V6V...
# Searching: mexican in V6W...
# Searching: mexican in V6X...
# Searching: mexican in V6Y...
# Searching: mexican in V7A...
# Searching: mexican in V7C...
# Searching: mexican in V7E...
# Searching: thai in V6V...
# Searching: thai in V6W...
# Searching: thai in V6X...
# Searching: thai in V6Y...
# Searching: thai in V7A...
# Searching: thai in V7C...
# Searching: thai in V7E...
# Searching: italian in V6V...
# Searching: italian in V6W...
# Searching: italian in V6X...
# Searching: italian in V6Y...
# Searching: italian in V7A...
# Searching: italian in V7C...
# Searching: italian in V7E...
# Searching: pizza in V6V...
# Searching: pizza in V6W...
# Searching: pizza in V6X...
# Searching: pizza in V6Y...
# Searching: pizza in V7A...
# Searching: pizza in V7C...
# Searching: pizza in V7E...
# Searching: burgers in V6V...
# Searching: burgers in V6W...
# Searching: burgers in V6X...
# Searching: burgers in V6Y...
# Searching: burgers in V7A...
# Searching: burgers in V7C...
# Searching: burgers in V7E...
#                          id                              name  \
# 0    y7_33jucQRo37eQEshPeMQ                   Shoestring Cafe
# 1    -rEA553gskIEHZteI5RExQ          Kirin Seafood Restaurant
# 2    pgyPhwk3lB1DxedDzygUUg                      The Fish Man
# 3    Hr5sm6NpE6K-98PrqHksbQ              Anar Persian Cuisine
# 4    R1KeQwYWkHczmZjSbfY2XA                    Shanghai River
# ..                      ...                               ...
# 467  GQcYVzki2lKT4psa8S4RZw                      Blenz Coffee
# 468  p4bEiFv80KGqdpHztWaD_Q           Good Co Bar - Steveston
# 469  iONl1L8eLbLmZFENHae41Q  Shady Island Seafood Bar & Grill
# 470  H2bdsjihdx-zQcJpWPjvGA             Yuwa Japanese Cuisine
# 471  hZ97IM49A_vZYvskxlZFZw                        Pho Anh Vu
#
#                                                address   latitude   longitude  \
# 0    4611 No 6 Road, Suite 180, Richmond, BC V6V 2L...  49.179874 -123.069558
# 1    7900 Westminster Hwy, 2nd Fl, Richmond, BC V6X...  49.169910 -123.137530
# 2    1170-8391 Alexandra Road, Richmond, BC V6X 1C3...  49.178466 -123.130252
# 3     12051 Third Avenue, Richmond, BC V7E 3A2, Canada  49.126127 -123.185905
# 4    7831 Westminster Highway, Richmond, BC V6X 4J4...  49.170740 -123.138480
# ..                                                 ...        ...         ...
# 467  3900 Bayview Street, Unit 105, Richmond, BC V7...  49.123761 -123.182118
# 468  4020 Bayview Street, Steveston, BC V7E 0B3, Ca...  49.123578 -123.180234
# 469  3800 Bayview Street, Richmond, BC V7E 6K7, Canada  49.123923 -123.183891
# 470     2775 W 16th Ave, Vancouver, BC V6K 4W7, Canada  49.257885 -123.168008
# 471  4751 Garden City Road, Unit 150, Richmond, BC ...  49.177868 -123.125541
#
#                           categories
# 0       French, Seafood, Steakhouses
# 1        Seafood, Dim Sum, Cantonese
# 2         Seafood, Chinese, Barbeque
# 3    Persian/Iranian, Middle Eastern
# 4        Chinese, Noodles, Dumplings
# ..                               ...
# 467         Coffee & Tea, Sandwiches
# 468              Bars, Chicken Wings
# 469                    Seafood, Bars
# 470                         Japanese
# 471                       Vietnamese
#
# [472 rows x 6 columns]

# %%
# manually add Domino's and Torake ---
params_list = [
    {'term': "Domino's Pizza", 'location': 'Richmond, BC'},
    {'term': "Torake", 'location': 'Richmond, BC'}
]

for params in params_list:
    params['limit'] = 1
    response = requests.get(SEARCH_ENDPOINT, headers=HEADERS, params=params)
    biz = response.json().get('businesses', [None])[0]
    if not biz or biz['id'] in df['id'].values:
        continue

    coords = biz['coordinates']
    df.loc[len(df)] = {
        'id': biz['id'],
        'name': biz['name'],
        'latitude': coords['latitude'],
        'longitude': coords['longitude'],
        'categories': ", ".join([cat['title'] for cat in biz.get('categories', [])]),
        'address': ", ".join(biz['location']['display_address']),
    }

df.reset_index(drop=True, inplace=True)
print(f"Final total restaurants: {len(df)}")
df
# Out:
# Final total restaurants: 474
#                          id                              name  \
# 0    y7_33jucQRo37eQEshPeMQ                   Shoestring Cafe
# 1    -rEA553gskIEHZteI5RExQ          Kirin Seafood Restaurant
# 2    pgyPhwk3lB1DxedDzygUUg                      The Fish Man
# 3    Hr5sm6NpE6K-98PrqHksbQ              Anar Persian Cuisine
# 4    R1KeQwYWkHczmZjSbfY2XA                    Shanghai River
# ..                      ...                               ...
# 469  iONl1L8eLbLmZFENHae41Q  Shady Island Seafood Bar & Grill
# 470  H2bdsjihdx-zQcJpWPjvGA             Yuwa Japanese Cuisine
# 471  hZ97IM49A_vZYvskxlZFZw                        Pho Anh Vu
# 472  v6GRZxd-96gojJrXKFcLdw                    Domino's Pizza
# 473  dU_EN01lKd5N4pkcZtZGAQ                            Torake
#
#                                                address   latitude   longitude  \
# 0    4611 No 6 Road, Suite 180, Richmond, BC V6V 2L...  49.179874 -123.069558
# 1    7900 Westminster Hwy, 2nd Fl, Richmond, BC V6X...  49.169910 -123.137530
# 2    1170-8391 Alexandra Road, Richmond, BC V6X 1C3...  49.178466 -123.130252
# 3     12051 Third Avenue, Richmond, BC V7E 3A2, Canada  49.126127 -123.185905
# 4    7831 Westminster Highway, Richmond, BC V6X 4J4...  49.170740 -123.138480
# ..                                                 ...        ...         ...
# 469  3800 Bayview Street, Richmond, BC V7E 6K7, Canada  49.123923 -123.183891
# 470     2775 W 16th Ave, Vancouver, BC V6K 4W7, Canada  49.257885 -123.168008
# 471  4751 Garden City Road, Unit 150, Richmond, BC ...  49.177868 -123.125541
# 472  9471 No. 2 Road, Unit 120, Richmond, BC V7E 2C...  49.144227 -123.159686
# 473   130-9471 No 2 Road, Richmond, BC V7E 2C9, Canada  49.144259 -123.159658
#
#                            categories
# 0        French, Seafood, Steakhouses
# 1         Seafood, Dim Sum, Cantonese
# 2          Seafood, Chinese, Barbeque
# 3     Persian/Iranian, Middle Eastern
# 4         Chinese, Noodles, Dumplings
# ..                                ...
# 469                     Seafood, Bars
# 470                          Japanese
# 471                        Vietnamese
# 472  Pizza, Chicken Wings, Sandwiches
# 473                          Japanese
#
# [474 rows x 6 columns]

# %% [markdown]
# ## Create Context Map

# %%
# m = folium.Map(location=[49.1666, -123.1336], zoom_start=13, tiles='CartoDB dark_matter')

# for _, row in df.iterrows():
#     folium.CircleMarker(
#         location=[row['latitude'], row['longitude']],
#         radius=1.5,
#         color='#00ffff',
#         fill=True,
#         fill_opacity=1,
#         stroke=False
#     ).add_to(m)

# m.save("richmond_restaurants_map.html")
# print("🌐 Map saved as richmond_restaurants_map.html")

# %%
# create your base map focused on richmond
m = folium.Map(location=[49.1666, -123.1336], zoom_start=13, tiles='CartoDB dark_matter')

# add all restauarants
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=1.5,
        color='#00ffff',
        fill=True,
        fill_opacity=1,
        stroke=False
    ).add_to(m)

# made torake red mark
folium.CircleMarker(
    location=[49.144259, -123.159658],
    radius=5,
    color='red',
    fill=True,
    fill_opacity=1,
    tooltip='Torake'
).add_to(m)    

# Load GeoJSON with bus stops
with open("stops.geojson") as f:
    bus_stop_data = json.load(f)

# add bus stops
for feature in bus_stop_data['features']:
    geom_type = feature['geometry']['type']
    coords = feature['geometry']['coordinates']

    if geom_type == 'Point':
        lon, lat = coords
        folium.CircleMarker(
            location=[lat, lon],
            radius=3,
            color='green',
            fill=True,
            fill_opacity=1,
            stroke=False,
            tooltip=feature['properties'].get('stop_name', 'Bus Stop')
        ).add_to(m)
        
# add legend
legend_html = '''
<div style="position: fixed; 
     bottom: 30px; left: 30px; width: 180px; height: 110px; 
     background-color: white; border:2px solid grey; z-index:9999; font-size:14px;
     padding: 10px;">
     <b>Legend</b><br>
     <i style="background: blue; width: 10px; height: 10px; float: left; margin-right: 5px; border-radius: 50%; display: inline-block;"></i> Restaurants<br>
     <i style="background: green; width: 10px; height: 10px; float: left; margin-right: 5px; border-radius: 50%; display: inline-block;"></i> Bus Stops<br>
     <i style="background: red; width: 10px; height: 10px; float: left; margin-right: 5px; border-radius: 50%; display: inline-block;"></i> Torake
</div>
'''

m.get_root().html.add_child(folium.Element(legend_html))

# save
m.save("richmond_restaurants_bus_stops.html")
m.save("context map.html")
print ("updated map")
# Out:
# updated map
